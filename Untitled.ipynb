# %%
import pyinputplus

# %%
pyinputplus.i
# Out:
# Enter your number :
#  dfd
# 'dfd' is not a number.
# Enter your number :
#  dfd
# 'dfd' is not a number.
# Enter your number :
#  fd
# 'fd' is not a number.
# Enter your number :
#  dfd
# 'dfd' is not a number.
# Enter your number :
#  12
# 12

# %%
# condition statement
# if
# elif
# else

# %%
database_username = "Sachin"
username_by_user = input("Etner your user name : ")
if database_username == username_by_user:
    print("correct password")  
else:
    print("wrong username")
# Out:
# Etner your user name :  Sachin
# correct password

# %%
if 33==33 and 66==67:
    print("both are equal")
else:
    print("both are not equal")
# Out:
# both are not equal

# %%
if False:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
# 0
# False
# ""
# [] False
# ()
# {}

# %%
# 1
# True
# "this"

# %%
list1 = ["apple",123]
if list1:
    print(f"Basket has {len(list1)} element")
else:
    print("Basket is empty")
# Out:
# Basket has 2 element

# %%
if 33 ==33:
    print("both 33 are equal")
if 44 == 44:
    print("both 44 are equal")
if 77 == 79:
    print("both 44 are equal")   
else:
    print("all above conditions are false")
# Out:
# both 33 are equal
# both 44 are equal
# all above conditions are false

# %%
if 33 ==35:
    print("both 33 are equal")
elif 44 == 49:
    print("both 44 are equal")
elif 77 == 79:
    print("both 77 are equal")   
else:
    print("all above conditions are false")
# Out:
# all above conditions are false

# %%
if 33 ==334:
    print("both 33 are equal")
    if 44 == 44:
        print("both 44 are equal ")
        if 55 ==55:
            print("both 55 are equal")
        else:
            print("I am 55 else block")
    else:
        print("44 else block")
else:
    print("i am 33 else block")

# %%
if 55==55:
